# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("exofop_tess_tois.csv")
exofop = pd.DataFrame(data)
#print(exofop)
exofop
# Out:
#          TIC ID      TOI Previous CTOI  Master priority  SG1A priority  \
# 0     231663901   101.01           NaN                4              5
# 1     149603524   102.01           NaN                5              5
# 2     336732616   103.01           NaN                5              5
# 3     231670397   104.01           NaN                5              5
# 4     144065872   105.01           NaN                5              5
# ...         ...      ...           ...              ...            ...
# 1697  318022259  1730.01           NaN                2              4
# 1698  318022259  1730.02           NaN                2              4
# 1699  371234684  1731.01           NaN                5              5
# 1700  470987100  1732.01           NaN                2              4
# 1701   53427308  1733.01           NaN                3              4
#
#       SG1B priority  SG2 priority  SG3 priority  SG4 priority  SG5 priority  \
# 0                 5             5             5             5             4
# 1                 5             5             5             5             5
# 2                 5             5             5             5             5
# 3                 5             5             5             5             5
# 4                 5             5             5             5             5
# ...             ...           ...           ...           ...           ...
# 1697              2             2             1             4             4
# 1698              2             2             1             4             4
# 1699              5             5             5             5             5
# 1700              2             2             1             4             4
# 1701              3             3             1             4             4
#
#       ...  Stellar log(g) error Stellar Radius (R_Sun) Stellar Radius error  \
# 0     ...                   NaN               0.860000                  NaN
# 1     ...                   NaN               1.280000                  NaN
# 2     ...                   NaN               1.400000                  NaN
# 3     ...                   NaN               2.070000                  NaN
# 4     ...                   NaN               1.130000                  NaN
# ...   ...                   ...                    ...                  ...
# 1697  ...              0.009144               0.532243             0.015809
# 1698  ...              0.009144               0.532243             0.015809
# 1699  ...              0.091395               1.299900             0.070352
# 1700  ...              0.011413               0.632571             0.018744
# 1701  ...              0.070000               1.500000             0.070000
#
#       Stellar Metallicity  Stellar Metallicity error    Sectors  \
# 0                     NaN                        NaN          1
# 1                    0.24                       0.05  1,2,3,4,6
# 2                     NaN                        NaN          1
# 3                     NaN                        NaN          1
# 4                     NaN                        NaN          1
# ...                   ...                        ...        ...
# 1697                  NaN                        NaN         20
# 1698                  NaN                        NaN         20
# 1699                 0.08                       0.10         20
# 1700                  NaN                        NaN         20
# 1701                  NaN                        NaN         20
#
#                                                Comments  \
# 0                                             WASP-46 b
# 1                                              WASP 62b
# 2                                                HATS-3
# 3                                               WASP-73
# 4                                               WASP-95
# ...                                                 ...
# 1697  odd-even difference but three transit events m...
# 1698                     second candidate in the system
# 1699                                           HAT-P-9b
# 1700                                                NaN
# 1701  Small depth-aperture correlation; odd/even not...
#
#       Date TOI Alerted (by TESS Project)  Date TOI Updated (by TESS Project)  \
# 0                               9/5/2018                          12/17/2019
# 1                               9/5/2018                          12/17/2019
# 2                               9/5/2018                          12/17/2019
# 3                               9/5/2018                          12/17/2019
# 4                               9/5/2018                          12/17/2019
# ...                                  ...                                 ...
# 1697                           2/19/2020                           2/19/2020
# 1698                           2/19/2020                           2/19/2020
# 1699                           2/19/2020                           2/19/2020
# 1700                           2/19/2020                           2/19/2020
# 1701                           2/20/2020                           2/20/2020
#
#       Date Modified (by ExoFOP-TESS)
# 0                          1/16/2020
# 1                          1/16/2020
# 2                          1/16/2020
# 3                          1/16/2020
# 4                          1/16/2020
# ...                              ...
# 1697                       2/20/2020
# 1698                       2/20/2020
# 1699                       2/20/2020
# 1700                       2/20/2020
# 1701                       2/20/2020
#
# [1702 rows x 53 columns]

# %% [markdown]
# # Distance vs Orbital Period

# %%
Period = exofop["Period (days)"]
P_Radius = exofop["Planet Radius (R_Earth)"]
Distance = (Period / 365.25)**(2/3)

# %%
plt.plot(Period, Distance, 'r.')
plt.xlabel("Period (Days)")
plt.ylabel("Distance (AU)")
# Out:
# Text(0, 0.5, 'Distance (AU)')

# %% [markdown]
# # Planetary Radius vs Orbital Period

# %%
plt.plot(Period, P_Radius, 'r.')
plt.xlabel("Period (Days)")
plt.ylabel("Planetary Radius (R_Earth)")
plt.xscale("log")
plt.yscale("log")

# %% [markdown]
# # Stellar Magnitude (Apparent from TESS) vs Planetary Radius

# %%
App_Mag = exofop["TESS mag"]

# %%
plt.plot(P_Radius, App_Mag, 'b.')
plt.xlabel("Planetary Radius (R_Earth)")
plt.ylabel("Apparent Magnitude (from TESS)")
# Out:
# Text(0, 0.5, 'Apparent Magnitude (from TESS)')

# %% [markdown]
# # Stellar Magnitude (Apparent from TESS) vs Stellar Radius

# %%
S_Radius = exofop["Stellar Radius (R_Sun)"]
plt.plot(S_Radius, App_Mag, 'b.')
plt.xlabel("Stellar Radius (R_Sun)")
plt.ylabel("Apparent Magnitude (from TESS)")
# Out:
# Text(0, 0.5, 'Apparent Magnitude (from TESS)')

# %% [markdown]
# # Stellar Magnitude (Absolute) vs Planetary Radius

# %%
Stellar_D = exofop["Stellar Distance (pc)"]
Stellar_Mag = App_Mag - 5*np.log10(Stellar_D) + 5

# %%
plt.plot(P_Radius, Stellar_Mag, 'g.')
plt.xlabel("Planetary Radius (R_Earth)")
plt.ylabel("Stellar Magnitude (Absolute)")
# Out:
# Text(0, 0.5, 'Stellar Magnitude (Absolute)')

# %% [markdown]
# # Stellar Magnitude vs Stellar Radius

# %%
plt.plot(S_Radius, Stellar_Mag, 'g.')
plt.xlabel("Stellar Radius (R_Sun)")
plt.ylabel("Stellar Magnitude (Absolute)")
# Out:
# Text(0, 0.5, 'Stellar Magnitude (Absolute)')

# %% [markdown]
# # Temp vs Planet Insolation

# %%
P_Insol = exofop["Planet Insolation (Earth flux)"]
P_Eq_Temp = exofop["Planet Eq Temp (K)"]

# %%
plt.plot(P_Insol, P_Eq_Temp, 'r.')
plt.xlabel("Planet Insolation (Earth Flux)")
plt.ylabel ("Planet Eq Temperature (K)")
# Out:
# Text(0, 0.5, 'Planet Eq Temperature (K)')
